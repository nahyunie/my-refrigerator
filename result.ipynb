# %%
from google.colab import drive
drive.mount('/content/drive')
#200000

# %%
# !pip uninstall tensorflow

# %%
import tensorflow as tf

tf.__version__

# %%
# !wget https://www.python.org/ftp/python/3.6.5/Python-3.6.5.tgz 
# !tar xvfz Python-3.6.5.tgz 
# !Python-3.6.5/configure 
# !make 
# !sudo make install

# %%
# !python --version

# %%
# %tensorflow_version 1.x

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
   raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
print(tf.__version__)

# %%
# !python '/content/drive/MyDrive/models/research/object_detection/xml_to_csv.py'

# %%
# !pip install tensorflow-object-detection-api

# %%
# !python '/content/drive/MyDrive/models/research/object_detection/generate_tfrecord.py' --csv_input='/content/drive/MyDrive/models/research/object_detection/datas/test_labels.csv'  --output_path='/content/drive/MyDrive/models/research/object_detection/record/test.record'  --image_dir='/content/drive/MyDrive/models/research/object_detection/images/test/'

# %%
# !python '/content/drive/MyDrive/models/research/object_detection/generate_tfrecord.py' --csv_input='/content/drive/MyDrive/models/research/object_detection/datas/train_labels.csv'  --output_path='/content/drive/MyDrive/models/research/object_detection/record/train.record'  --image_dir='/content/drive/MyDrive/models/research/object_detection/images/train/'

# %%
# !pip install tensorflow==1.14

# %%
# !git clone https://github.com/tensorflow/models

# %%
# !git clone https://github.com/cocodataset/cocoapi.git

# %%
# !python '/content/drive/MyDrive/models/research/object_detection/train.py' --train_dir='/content/drive/MyDrive/models/research/object_detection/training/' --pipeline_config_path=/content/drive/MyDrive/models/research/object_detection/training/ssd_mobilenet_v2_quantized_300x300_coco.config

# %%
# %cd /content/drive/MyDrive/models/research/slim

# !python setup.py build
# !python setup.py install

# %%
# !tf_upgrade_v2 --intree /content/drive/MyDrive/a1/train.py --outtree /content/drive/MyDrive/a1/train.py-upgraded --copyotherfiles False

# %%
# !python /content/models/research/object_detection/builders/model_builder_test.py

# %%
tf_upgrade_v2 --infile tensorfoo.py --outfile tensorfoo-upgraded.py

# %%
import os
import pathlib

# Clone the tensorflow models repository if it doesn't already exist
if "models" in pathlib.Path.cwd().parts:
  while "models" in pathlib.Path.cwd().parts:
    os.chdir('..')
elif not pathlib.Path('models').exists():
  # !git clone --depth 1 https://github.com/tensorflow/models

# %%
# %%bash
# cd /content/drive/MyDrive/models/research/
# protoc object_detection/protos/*.proto --python_out=.
# cp object_detection/packages/tf1/setup.py .
# python -m pip install .

# %%
import os
os.environ['PYTHONPATH'] += ':/content/drive/MyDrive/models/research/:/content/drive/MyDrive/models/research/slim'

# %%
# !python /content/drive/MyDrive/models/research/slim/setup.py build
# !python /content/drive/MyDrive/models/research/slim/setup.py install

# %%
import matplotlib
import matplotlib.pyplot as plt

import os
import random
import io
import imageio
import glob
import scipy.misc
import numpy as np
from six import BytesIO
from PIL import Image, ImageDraw, ImageFont
from IPython.display import display, Javascript
from IPython.display import Image as IPyImage

import tensorflow as tf

from object_detection.utils import label_map_util
from object_detection.utils import config_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.utils import colab_utils
from object_detection.builders import model_builder

# %matplotlib inline

# %%
# !pip install object_detection

# %%
# !python /content/drive/MyDrive/models/research/object_detection/builders/model_builder_test.py

# %%
# !pip install scipy

# %%
pip install "numpy<1.17"

# %%
# !python /content/drive/MyDrive/models/research/object_detection/export_inference_graph.py --input_type image_tensor --pipeline_config_path /content/drive/MyDrive/models/research/object_detection/training/ssd_mobilenet_v2_quantized_300x300_coco.config --trained_checkpoint_prefix /content/drive/MyDrive/models/research/object_detection/training/model.ckpt-50 --output_directory inference_graph

# %%
# !python /content/drive/MyDrive/models/research/object_detection/export_tflite_ssd_graph.py --pipeline_config_path=/content/drive/MyDrive/models/research/object_detection/training/ssd_mobilenet_v2_quantized_300x300_coco.config --trained_checkpoint_prefix=/content/drive/MyDrive/models/research/object_detection/training/model.ckpt-50 --output_directory=/content/drive/MyDrive/tflite --add_postprocessing_op=true

# %%
# !tflite_convert --graph_def_file=/content/drive/MyDrive/tflite/tflite_graph.pb --output_file=/content/drive/MyDrive/tflite/detect.tflite --output_format=TFLITE --input_shapes=1,300,300,3 --input_arrays=normalized_input_image_tensor --output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' --inference_type=QUANTIZED_UINT8 --mean_values=128 --std_dev_values=127 --change_concat_input_ranges=false --allow_custom_ops

# %%
# !python /content/drive/MyDrive/metadata_writer_for_image_classifier.py --model_file=/content/drive/MyDrive/tflite/detect.tflite --label_file=/content/drive/MyDrive/tflite/labelmap1.txt --export_directory=/content/drive/MyDrive/tflite

# %%
import json

from pykafka import KafkaClient
from pykafka.common import OffsetType

# omitting our internal hosts since I don't know if that's cool to share
hosts = {}
# If this consumer_group is modified, it must also be modified in
# Casterisk's munin_measures/kafka_lag.py

kafka_client = KafkaClient(hosts)
consumer = kafka_client.topics['crawled_items'].get_simple_consumer(
    auto_offset_reset=OffsetType.LATEST, reset_offset_on_start=True)
msg = consumer.consume()
print(json.loads(msg.value))

# %%
# !pip install pykafka

# %%
# !pip install flatbuffers

# %%
# !pip install tflite_support

# %%
# !python /content/drive/MyDrive/models/research/object_detection/builders/model_builder_test.py

# %%
# !apt-get install protobuf-compiler python-pil python-lxml python-tk
# !pip install Cython

# %%
# !apt-get install -y -qq protobuf-compiler python-pil python-lxml

# %%
import time, psutil
Start = time.time()- psutil.boot_time()
Left= 12*3600 - Start
print('Time remaining for this session is: ', Left/3600)

# %%
# %cd /content/drive/MyDrive/models/research/
# !protoc object_detection/protos/*.proto --python_out=.

# %%
import os
os.environ['PYTHONPATH'] += ':/content/drive/MyDrive/models/research/:/content/drive/MyDrive/models/research/slim'

# %%
# !python setup.py build
# !python setup.py install

# %%
# !pip install scipy==1.0.1

# %%
# !pip install scikit-build

# %% [markdown]
# import parameterized
#
# import text_format
# import model_builder
# from object_detection.meta_architectures import faster_rcnn_meta_arch
# from object_detection.meta_architectures import rfcn_meta_arch
# from object_detection.meta_architectures import ssd_meta_arch
# from object_detection.protos import hyperparams_pb2
# from object_detection.protos import losses_pb2
# from object_detection.protos import model_pb2
# from object_detection.utils import test_case

# %%
# !python /content/drive/MyDrive/models/research/object_detection/builders/model_builder_test.py

# %%
pip install "numpy<1.17"

# %%
# !pip install setuptools==9.0.1.

# %%
# !python3 -m ensurepip --upgrade

# %%
pip install --upgrade pip

# %%
pip install matplotlib

# %%
# !python /content/drive/MyDrive/aa/test.py

# %%
# !pip install string_int_label_map_pb2

# %%
# !pip install object_detection

# %%
# !pip install ipykernel

# %%
# !pip install matplotlib

# %%
# !pip install numpy

# %%
# !pip install six

# %% [markdown]
# start

# %%
# %tensorflow_version 1.x

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
   raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
print(tf.__version__)

# %%
# !apt-get install protobuf-compiler python-pil python-lxml python-tk
# !pip install Cython

# %%
# %cd /content/drive/MyDrive/models/research/
# !protoc object_detection/protos/*.proto --python_out=.

# %%
import os
os.environ['PYTHONPATH'] += ':/content/drive/MyDrive/models/research/:/content/drive/MyDrive/models/research/slim'

# %%
# !python setup.py build
# !python setup.py install

# %%
# !python /content/drive/MyDrive/models/research/object_detection/builders/model_builder_tf1_test.py

# %%
# !python /content/drive/MyDrive/models/research/object_detection/xml_to_csv.py

# %%
# !python /content/drive/MyDrive/models/research/object_detection/generate_tfrecord.py --/content/drive/MyDrive/models/research/object_detection/datas/test_labels.csv  --output_path=/content/drive/MyDrive/models/research/object_detection/record/test.record  --image_dir=/content/drive/MyDrive/models/research/object_detection/images/test

# %%
# !python /content/drive/MyDrive/models/research/object_detection/generate_tfrecord.py --label='ARDUINO DEVICE' --csv_input=/content/drive/MyDrive/models/research/object_detection/datas/test_labels.csv  --output_path=/content/drive/MyDrive/models/research/object_detection/record/test.record  --image_dir=/content/drive/MyDrive/models/research/object_detection/images/test

# %%
# !python /content/drive/MyDrive/models/research/object_detection/generate_tfrecord.py --label='ARDUINO DEVICE' --csv_input=/content/drive/MyDrive/models/research/object_detection/datas/train_labels.csv  --output_path=/content/drive/MyDrive/models/research/object_detection/record/train.record  --image_dir=/content/drive/MyDrive/models/research/object_detection/images/train

# %%
# !git clone https://github.com/cocodataset/cocoapi.git

# %%
# %cd /content/drive/MyDrive/cocoapi/PythonAPI
# !sudo make

# %%
# !cp -r pycocotools /content/drive/MyDrive/models/research/

# %% [markdown]
# 0401 PM 4:40 여기까지 했음
#
#
# # **아래 train.py부터 실행하면 됨 **
#
# 진은혜 화이팅 콱 씨

# %%
# !python /content/drive/MyDrive/models/research/object_detection/train.py --train_dir=/content/drive/MyDrive/models/research/object_detection/training/ --pipeline_config_path=/content/drive/MyDrive/models/research/object_detection/training/ssd_mobilenet_v2_quantized_300x300_coco.config

# %%
# !python /content/drive/MyDrive/models/research/object_detection/export_inference_graph.py --input_type image_tensor --pipeline_config_path /content/drive/MyDrive/models/research/object_detection/training/ssd_mobilenet_v2_quantized_300x300_coco.config --trained_checkpoint_prefix /content/drive/MyDrive/models/research/object_detection/training/model.ckpt-90000 --output_directory /content/drive/MyDrive/models/research/object_detection/inference_graph/

# %%
# !python /content/drive/MyDrive/models/research/object_detection/export_tflite_ssd_graph.py --pipeline_config_path=/content/drive/MyDrive/models/research/object_detection/training/ssd_mobilenet_v2_quantized_300x300_coco.config --trained_checkpoint_prefix=/content/drive/MyDrive/models/research/object_detection/training/model.ckpt-90000 --output_directory=/content/drive/MyDrive/models/tflite --add_postprocessing_op=true

# %%
# !tflite_convert --graph_def_file=/content/drive/MyDrive/models/tflite/tflite_graph.pb --output_file=/content/drive/MyDrive/models/tflite/detect.tflite --output_format=TFLITE --input_shapes=1,300,300,3 --input_arrays=normalized_input_image_tensor --output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' \ --inference_type=QUANTIZED_UINT8 --mean_values=128 --std_dev_values=127 --change_concat_input_ranges=false --allow_custom_ops

# %%
# !pip install tflite-support

# %%
# !pip install tflite_support_nightly

# %%
from tflite_support.metadata_writers import object_detector
from tflite_support.metadata_writers import writer_utils
from tflite_support import metadata

ObjectDetectorWriter = object_detector.MetadataWriter
_MODEL_PATH = "/content/drive/MyDrive/models/tflite/detect.tflite"
_LABEL_FILE = "/content/drive/MyDrive/models/tflite/labelmapp.txt"
_SAVE_TO_PATH = "/content/drive/MyDrive/models/tflite/metadata.tflite"

writer = ObjectDetectorWriter.create_for_inference(
    writer_utils.load_file(_MODEL_PATH), [127.5], [127.5], [_LABEL_FILE])
writer_utils.save_file(writer.populate(), _SAVE_TO_PATH)

# Verify the populated metadata and associated files.
displayer = metadata.MetadataDisplayer.with_model_file(_SAVE_TO_PATH)
print("Metadata populated:")
print(displayer.get_metadata_json())
print("Associated file(s) populated:")
print(displayer.get_packed_associated_file_list())
